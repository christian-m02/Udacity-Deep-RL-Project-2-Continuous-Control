# %% [markdown]
# # Continuous Control - Parameter Study
#
# ---
#
# This notebook uses the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# This notebook contains the hyperparameter study for the accompanying Report.pdf. I identified settings that enable the agent to attain the target average score. For conciseness, those two agents along with the final hyperparameters are also presented in Continuous_Control.ipynb on their own.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
import sys
print(sys.version)
# Out:
# 3.6.3 | packaged by conda-forge | (default, Nov  4 2017, 10:10:56)
# [GCC 4.8.2 20140120 (Red Hat 4.8.2-15)]

# %%
# !pip -q install ./python  #takes care of dependencies; for running in Udacity's workspace

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

from unityagents import UnityEnvironment
from collections import deque
from ddpg_agent import Agent
from workspace_utils import active_session
from workspace_utils import keep_awake

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
from unityagents import UnityEnvironment
import numpy as np

# select this option to load version 1 (with a single agent) of the environment
env = UnityEnvironment(file_name='/data/Reacher_One_Linux_NoVis/Reacher_One_Linux_NoVis.x86_64')

# select this option to load version 2 (with 20 agents) of the environment
# env = UnityEnvironment(file_name='/data/Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %%
# env = UnityEnvironment(file_name="Reacher.app")

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 1
# Size of each action: 4
# There are 1 agents. Each observes a state with length: 33
# The state for the first agent looks like: [  0.00000000e+00  -4.00000000e+00   0.00000000e+00   1.00000000e+00
#   -0.00000000e+00  -0.00000000e+00  -4.37113883e-08   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00  -1.00000000e+01   0.00000000e+00
#    1.00000000e+00  -0.00000000e+00  -0.00000000e+00  -4.37113883e-08
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   5.75471878e+00  -1.00000000e+00
#    5.55726671e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#   -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
# env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
# states = env_info.vector_observations                  # get the current state (for each agent)
# scores = np.zeros(num_agents)                          # initialize the score (for each agent)
# while True:
#     actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
#     actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
#     env_info = env.step(actions)[brain_name]           # send all actions to tne environment
#     next_states = env_info.vector_observations         # get next state (for each agent)
#     rewards = env_info.rewards                         # get reward (for each agent)
#     dones = env_info.local_done                        # see if episode finished
#     scores += env_info.rewards                         # update the score (for each agent)
#     states = next_states                               # roll over states to next time step
#     if np.any(dones):                                  # exit loop if episode finished
#         break
# print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %%
#env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %% [markdown]
# ### 5. Train the Agent

# %%
def train(n_episodes=500, max_t=1000, path_name='checkpoint'):
    scores = []                        # list containing scores from each episode
    scores_deque = deque(maxlen=100)   # last 100 scores
    scores_deque_mean = []             # list containing the mean of trailing scores window from each episode
    solved = False                     # if the task has been solved / average score been achieved
    
    max_score = -np.Inf
    
    #for i_episode in range(1, n_episodes+1):
    for i_episode in keep_awake(range(1, n_episodes+1)):
        env_info = env.reset(train_mode=True)[brain_name]   # reset the environment
        state = env_info.vector_observations[0]             # get the current state
        
        agent.reset()
        
        score = 0
        #for t in range(max_t):
        for t in keep_awake(range(max_t)):
            action = agent.act(state)
            
            env_info = env.step(action)[brain_name]        # send the action to the environment
            next_state = env_info.vector_observations[0]   # get the next state
            reward = env_info.rewards[0]                   # get the reward
            done = env_info.local_done[0]                  # see if episode has finished
            
            agent.step(state, action, reward, next_state, done)
            
            state = next_state
            score += reward
            if done:
                break 
                
        scores.append(score)
        scores_deque.append(score)
        scores_deque_mean.append(np.mean(scores_deque))
        
        print('\rEpisode {}\tAverage Score: {:.2f}\tScore: {:.2f}'.format(i_episode, np.mean(scores_deque), score), end="")
        if i_episode % 25 == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))   
        if np.mean(scores_deque)>=30.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode-100, np.mean(scores_deque)))
            torch.save(agent.actor_local.state_dict(), path_name + '_actor.pth')
            torch.save(agent.critic_local.state_dict(), path_name + '_critic.pth')
            solved = True
            break
        if i_episode > 100 and np.mean(scores_deque) < 5.0: # check if reasonable progress has been made
            print('\nGiving up: Already {:d} episodes!\tAnd Average Score only: {:.2f}'.format(i_episode, np.mean(scores_deque)))
            print('\nNeed to look for another hyperparameter combination !')
            break
    return scores, scores_deque_mean, i_episode-100, solved

# %%
plt.rcParams.update({'font.size': 30})
def plot_scores(scores, scores_deque_mean, method, num_episodes_solved, solved=False, full_run=True):
    fig = plt.figure(figsize=(40, 20))
    ax = fig.add_subplot(111)
    if full_run:
        ax.axhline(y=30., xmin=0.0, xmax=1.0, color='r', linestyle='--', linewidth=2.0, dashes=(5, 10))
    if solved:
        ax.set_title('Scores and Mean of trailing scores window for ' + method + ' (solved in ' + str(num_episodes_solved) + ' episodes)')
    else:
        ax.set_title('Scores and Mean of trailing scores window for ' + method)
    plt.plot(np.arange(1, len(scores)+1), scores, label='scores')
    plt.plot(np.arange(1, len(scores_deque_mean)+1), scores_deque_mean, label='scores window mean', c='r', linewidth=2.0)
    plt.ylabel('Score')
    plt.xlabel('Episode #')
    plt.legend(loc='upper left');
    plt.show()
    fig.savefig('scores ' + method + '.png', format='png')

# %% [markdown]
# #### ======================================================================
#
# ### 6. Train the DDPG agent - Explore various hyperparameter settings
#
# #### ======================================================================

# %% [markdown]
# ### 00. baseline / reference case - use default parameter settings

# %%
# 00. baseline / reference case - use default parameter settings except for the number of nodes / units in hidden layers
#     (the effect of the number of nodes will be assessed at a later stage, see case 06 below)

agent = Agent(state_size=state_size, action_size=action_size, 
              actor_fc1_units = 128,  actor_fc2_units = 128, 
              critic_fc1_units = 128, critic_fc2_units = 128)

with active_session():
    scores, scores_mean, num_episodes_solved, solved = train(n_episodes=100, path_name='checkpoint_00')
    
print('\rscores_mean[-1]: {:.2f}'.format(scores_mean[-1]))
plot_scores(scores, scores_mean, 'DDPG - baseline', num_episodes_solved, solved, full_run=False)
# Out:
# Episode 25	Average Score: 0.13	Score: 0.00
# Episode 50	Average Score: 0.23	Score: 1.19
# Episode 75	Average Score: 0.40	Score: 1.30
# Episode 100	Average Score: 0.59	Score: 1.02
# scores_mean[-1]: 0.59

# %% [markdown]
# ### Observations:
#
# The 'baseline' agent's learning is very slow, too slow.

# %% [markdown]
# ### 01. OU noise Standard Deviation
# Try different values for the standard deviation sigma in the OU noise. Default value of sigma is 0.2, as in 00. baseline above.
#
# 01a: sigma = 0.30
#
# 01b: sigma = 0.20 (default) as in 00. baseline above
#
# 01c: sigma = 0.10
#
# 01d: sigma = 0.05

# %% [markdown]
# ### 01.a OU noise Standard Deviation sigma = 0.30

# %%
agent = Agent(state_size=state_size, action_size=action_size, 
              actor_fc1_units = 128,  actor_fc2_units = 128, 
              critic_fc1_units = 128, critic_fc2_units = 128,
              sigma = 0.30)              

with active_session():
    scores, scores_mean, num_episodes_solved, solved = train(n_episodes=100, path_name='checkpoint_01a')
    
print('\rscores_mean[-1]: {:.2f}'.format(scores_mean[-1]))
plot_scores(scores, scores_mean, 'DDPG - OU sigma = 0.30', num_episodes_solved, solved, full_run=False)
# Out:
# Episode 25	Average Score: 0.05	Score: 0.00
# Episode 50	Average Score: 0.12	Score: 0.00
# Episode 75	Average Score: 0.14	Score: 0.52
# Episode 100	Average Score: 0.20	Score: 0.08
# scores_mean[-1]: 0.20

# %% [markdown]
# ### 01.b OU noise Standard Deviation sigma = 0.20
#
# This is the same as 00. baseline / reference case above, since sigma = 0.20 is the default.

# %% [markdown]
# ### 01.c OU noise Standard Deviation sigma = 0.10

# %%
agent = Agent(state_size=state_size, action_size=action_size, 
              actor_fc1_units = 128,  actor_fc2_units = 128, 
              critic_fc1_units = 128, critic_fc2_units = 128,
              sigma = 0.10)              

with active_session():
    scores, scores_mean, num_episodes_solved, solved = train(n_episodes=100, path_name='checkpoint_01c')
    
print('\rscores_mean[-1]: {:.2f}'.format(scores_mean[-1]))
plot_scores(scores, scores_mean, 'DDPG - OU sigma = 0.10', num_episodes_solved, solved, full_run=False)
# Out:
# Episode 25	Average Score: 0.55	Score: 0.63
# Episode 50	Average Score: 0.64	Score: 0.06
# Episode 75	Average Score: 0.62	Score: 1.07
# Episode 100	Average Score: 0.66	Score: 0.20
# scores_mean[-1]: 0.66

# %% [markdown]
# ### 01.d OU noise Standard Deviation sigma = 0.05

# %%
agent = Agent(state_size=state_size, action_size=action_size, 
              actor_fc1_units = 128,  actor_fc2_units = 128, 
              critic_fc1_units = 128, critic_fc2_units = 128,
              sigma = 0.05)              

with active_session():
    scores, scores_mean, num_episodes_solved, solved = train(n_episodes=100, path_name='checkpoint_01d')
    
print('\rscores_mean[-1]: {:.2f}'.format(scores_mean[-1]))
plot_scores(scores, scores_mean, 'DDPG - OU sigma = 0.05', num_episodes_solved, solved, full_run=False)
# Out:
# Episode 25	Average Score: 0.58	Score: 0.52
# Episode 50	Average Score: 0.82	Score: 1.09
# Episode 75	Average Score: 0.97	Score: 2.64
# Episode 100	Average Score: 1.01	Score: 0.48
# scores_mean[-1]: 1.01

# %% [markdown]
# ### Observations:
#
# => sigma = 0.05 yields the most improvement of the learning curve
#
# => Going forward, use sigma = 0.05

# %% [markdown]
# ### 02. Learning Rates Actor and Critic
#
# 02.a: LR_ACTOR = 1e-4, LR_CRITIC = 1e-3  (default)
#
# 02.b: LR_ACTOR = 1e-4, LR_CRITIC = 1e-4
#
# 02.c: LR_ACTOR = 3e-4, LR_CRITIC = 3e-4
#
# 02.d: LR_ACTOR = 5e-4, LR_CRITIC = 5e-4

# %% [markdown]
# ### 02.a  LR_ACTOR = 1e-4, LR_CRITIC = 1e-3
#
# This is the same as case 01.d above, since LR_ACTOR = 1e-4, LR_CRITIC = 1e-3 is the default.

# %% [markdown]
# ### 02.b LR_ACTOR = 1e-4, LR_CRITIC = 1e-4

# %%
agent = Agent(state_size=state_size, action_size=action_size, 
              actor_fc1_units = 128,  actor_fc2_units = 128, 
              critic_fc1_units = 128, critic_fc2_units = 128,
              sigma = 0.05,
              LR_ACTOR = 1e-4, LR_CRITIC = 1e-4)

with active_session():
    scores, scores_mean, num_episodes_solved, solved = train(n_episodes=100, path_name='checkpoint_02b')
    
print('\rscores_mean[-1]: {:.2f}'.format(scores_mean[-1]))
plot_scores(scores, scores_mean, 'DDPG - LR_ACTOR = 1e-4, LR_CRITIC = 1e-4', num_episodes_solved, solved, full_run=False)
# Out:
# Episode 25	Average Score: 0.87	Score: 0.80
# Episode 50	Average Score: 1.64	Score: 3.05
# Episode 75	Average Score: 2.17	Score: 3.55
# Episode 100	Average Score: 2.88	Score: 3.86
# scores_mean[-1]: 2.88

# %% [markdown]
# ### 02.c LR_ACTOR = 3e-4, LR_CRITIC = 3e-4

# %%
agent = Agent(state_size=state_size, action_size=action_size, 
              actor_fc1_units = 128,  actor_fc2_units = 128, 
              critic_fc1_units = 128, critic_fc2_units = 128,
              sigma = 0.05,
              LR_ACTOR = 3e-4, LR_CRITIC = 3e-4)              

with active_session():
    scores, scores_mean, num_episodes_solved, solved = train(n_episodes=100, path_name='checkpoint_02c')
    
print('\rscores_mean[-1]: {:.2f}'.format(scores_mean[-1]))
plot_scores(scores, scores_mean, 'DDPG - LR_ACTOR = 3e-4, LR_CRITIC = 3e-4', num_episodes_solved, solved, full_run=False)
# Out:
# Episode 25	Average Score: 1.03	Score: 1.89
# Episode 50	Average Score: 1.57	Score: 3.51
# Episode 75	Average Score: 1.99	Score: 1.16
# Episode 100	Average Score: 2.15	Score: 1.91
# scores_mean[-1]: 2.15

# %% [markdown]
# ### 02.d LR_ACTOR = 5e-4, LR_CRITIC = 5e-4

# %%
agent = Agent(state_size=state_size, action_size=action_size, 
              actor_fc1_units = 128,  actor_fc2_units = 128, 
              critic_fc1_units = 128, critic_fc2_units = 128,
              sigma = 0.05,
              LR_ACTOR = 5e-4, LR_CRITIC = 5e-4)              

with active_session():
    scores, scores_mean, num_episodes_solved, solved = train(n_episodes=100, path_name='checkpoint_02d')
    
print('\rscores_mean[-1]: {:.2f}'.format(scores_mean[-1]))
plot_scores(scores, scores_mean, 'DDPG - LR_ACTOR = 5e-4, LR_CRITIC = 5e-4', num_episodes_solved, solved, full_run=False)
# Out:
# Episode 25	Average Score: 1.12	Score: 2.53
# Episode 50	Average Score: 1.76	Score: 6.00
# Episode 75	Average Score: 2.32	Score: 4.20
# Episode 100	Average Score: 2.81	Score: 2.90
# scores_mean[-1]: 2.81

# %% [markdown]
# ### Observations:
#
# => 02.b LR_ACTOR = 1e-4, LR_CRITIC = 1e-4 yields the best learning curve, with 02.d LR_ACTOR = 5e-4, LR_CRITIC = 5e-4 a close second
#
# => Going forward, use LR_ACTOR = 1e-4, LR_CRITIC = 1e-4

# %% [markdown]
# ### Next Step:
#
# Now do a full run to see how it goes.

# %%
agent = Agent(state_size=state_size, action_size=action_size, 
              actor_fc1_units = 128,  actor_fc2_units = 128, 
              critic_fc1_units = 128, critic_fc2_units = 128,
              sigma = 0.05,
              LR_ACTOR = 1e-4, LR_CRITIC = 1e-4)

with active_session():
    scores_full, scores_mean_full, num_episodes_solved_full, solved = train(n_episodes=500, path_name='checkpoint_02b_full')
    
print('\rscores_mean[-1]: {:.2f}'.format(scores_mean_full[-1]))
plot_scores(scores_full, scores_mean_full, 'DDPG - LR_ACTOR = 1e-4, LR_CRITIC = 1e-4, full run', num_episodes_solved_full, solved, full_run=True)
# Out:
# Episode 25	Average Score: 0.64	Score: 1.13
# Episode 50	Average Score: 1.46	Score: 2.14
# Episode 75	Average Score: 2.20	Score: 1.84
# Episode 100	Average Score: 3.08	Score: 8.38
# Episode 101	Average Score: 3.12	Score: 4.36
# Giving up - It is not getting anywhwere: Already 101 episodes!	And Average Score only: 3.12
#
# Need to look for another hyperparameter combination !
# scores_mean[-1]: 3.12

# %% [markdown]
# ### Observations:
#
# => Admittedly, above learning curve does not look that bad but progress is still slow.
#
# => Adjusting only OU noise Standard Deviation and learning rates for Actor / Critic
# does not sufficiently improve the learning.
#
# => Let's consider something else such as batch normalization and see if this can further accelerate the learning.

# %% [markdown]
# ### 03. Batch Normalization

# %%
agent = Agent(state_size=state_size, action_size=action_size, 
              actor_fc1_units = 128,  actor_fc2_units = 128, 
              critic_fc1_units = 128, critic_fc2_units = 128,
              sigma = 0.05,
              LR_ACTOR = 1e-4, LR_CRITIC = 1e-4,
              use_BatchNorm=True)

with active_session():
    scores, scores_mean, num_episodes_solved, solved = train(n_episodes=500, path_name='checkpoint_03a')
    
print('\rscores_mean[-1]: {:.2f}'.format(scores_mean[-1]))
plot_scores(scores, scores_mean, 'DDPG - with batch normalization', num_episodes_solved, solved, full_run=True)
# Out:
# Episode 25	Average Score: 0.79	Score: 0.98
# Episode 50	Average Score: 1.55	Score: 2.06
# Episode 75	Average Score: 2.48	Score: 5.55
# Episode 100	Average Score: 4.25	Score: 10.44
# Episode 101	Average Score: 4.36	Score: 12.42
# Giving up - It is not getting anywhwere: Already 101 episodes!	And Average Score only: 4.36
#
# Need to look for another hyperparameter combination !
# scores_mean[-1]: 4.36

# %% [markdown]
# ### Observations:
#
# => Batch normalization improves learning a little bit, but initial progress still not that fast.
#
# => How would it be for the learning rates actor / critic above that came in as a close second, i.e. case 02.d ?

# %%
agent = Agent(state_size=state_size, action_size=action_size, 
              actor_fc1_units = 128,  actor_fc2_units = 128, 
              critic_fc1_units = 128, critic_fc2_units = 128,
              sigma = 0.05,
              LR_ACTOR = 5e-4, LR_CRITIC = 5e-4,
              use_BatchNorm=True)

with active_session():
    scores, scores_mean, num_episodes_solved, solved = train(n_episodes=500, path_name='checkpoint_03b')
    
print('\rscores_mean[-1]: {:.2f}'.format(scores_mean[-1]))
plot_scores(scores, scores_mean, 'DDPG - with batch normalization', num_episodes_solved, solved, full_run=True)
# Out:
# Episode 25	Average Score: 1.56	Score: 2.16
# Episode 50	Average Score: 3.23	Score: 8.55
# Episode 75	Average Score: 4.49	Score: 5.768
# Episode 100	Average Score: 8.28	Score: 33.68
# Episode 125	Average Score: 14.07	Score: 36.26
# Episode 150	Average Score: 20.77	Score: 28.53
# Episode 175	Average Score: 27.38	Score: 31.28
# Episode 200	Average Score: 28.97	Score: 32.73
# Episode 216	Average Score: 30.06	Score: 36.45
# Environment solved in 116 episodes!	Average Score: 30.06
# scores_mean[-1]: 30.06

# %% [markdown]
# ### Observations:
#
# => That looks much better.
#
# => Great - This is the first combination of hyperparameter settings for which the DDPG agent achieves the target average score of +30.
#
# => So batch normalization seems to have a profound impact on the learning in this case.
#
# => Going forward, use batch normalization.
#
# => And it seems that a learning rate of LR_ACTOR = 5e-4, LR_CRITIC = 5e-4 (case 02.d) works better with batch normalization than a learning rate of LR_ACTOR = 1e-4, LR_CRITIC = 1e-4 (case 02.b).
#
# => Let's look at a couple of other hyperparameters to check their effect on the agent's learning and see if learning can further be accelerated.

# %% [markdown]
# ### 04. Gradient clipping

# %%
agent = Agent(state_size=state_size, action_size=action_size, 
              actor_fc1_units = 128,  actor_fc2_units = 128, 
              critic_fc1_units = 128, critic_fc2_units = 128,
              sigma = 0.05,
              LR_ACTOR = 5e-4, LR_CRITIC = 5e-4,
              use_BatchNorm=True,
              use_clipping=True)

with active_session():
    scores, scores_mean, num_episodes_solved, solved = train(n_episodes=500, path_name='checkpoint_04')
    
print('\rscores_mean[-1]: {:.2f}'.format(scores_mean[-1]))
plot_scores(scores, scores_mean, 'DDPG - with gradient clipping', num_episodes_solved, solved, full_run=True)
# Out:
# /home/workspace/ddpg_agent.py:191: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(self.critic_local.parameters(), 1)
# Episode 25	Average Score: 1.56	Score: 2.16
# Episode 50	Average Score: 3.23	Score: 8.55
# Episode 75	Average Score: 4.49	Score: 5.768
# Episode 100	Average Score: 8.28	Score: 33.68
# Episode 114	Average Score: 11.26	Score: 15.86

# %% [markdown]
# ### Observations:
#
# => Gradient clipping surprisingly does not make any difference in this case.
#
# => Going forward, do not use gradient clipping.

# %% [markdown]
# ### 5. Size of the mini-batches
#
# 05.a: BATCH_SIZE = 64
#
# 05.b: BATCH_SIZE = 128
#
# 05.c: BATCH_SIZE = 256

# %% [markdown]
# ### 05.a: BATCH_SIZE = 64

# %%
agent = Agent(state_size=state_size, action_size=action_size, 
              actor_fc1_units = 128, actor_fc2_units = 128, 
              critic_fc1_units = 128, critic_fc2_units = 128, 
              sigma = 0.05, 
              LR_ACTOR = 5e-4, LR_CRITIC = 5e-4,
              use_BatchNorm=True,
              use_clipping=False,
              BATCH_SIZE = 64)

with active_session():
    scores, scores_deque_mean, num_episodes_solved, solved = train(n_episodes=500, path_name='checkpoint_05a')
    
print('\rscores_deque_mean[-1]: {:.2f}'.format(scores_deque_mean[-1]))
plot_scores(scores, scores_deque_mean, 'DDPG - BATCH_SIZE = 64', num_episodes_solved, solved, full_run=True)
# Out:
# Episode 25	Average Score: 1.05	Score: 2.27
# Episode 50	Average Score: 2.61	Score: 9.97
# Episode 75	Average Score: 4.08	Score: 7.151
# Episode 100	Average Score: 5.35	Score: 6.60
# Episode 125	Average Score: 7.80	Score: 6.413
# Episode 150	Average Score: 10.23	Score: 15.94
# Episode 175	Average Score: 12.06	Score: 18.47
# Episode 200	Average Score: 14.30	Score: 24.29
# Episode 225	Average Score: 16.89	Score: 30.70
# Episode 250	Average Score: 20.26	Score: 35.68
# Episode 275	Average Score: 22.92	Score: 4.470
# Episode 300	Average Score: 25.27	Score: 30.36
# Episode 325	Average Score: 27.33	Score: 27.19
# Episode 350	Average Score: 27.02	Score: 17.26
# Episode 375	Average Score: 28.91	Score: 32.75
# Episode 400	Average Score: 29.02	Score: 18.25
# Episode 425	Average Score: 29.30	Score: 35.02
# Episode 432	Average Score: 30.05	Score: 20.24
# Environment solved in 332 episodes!	Average Score: 30.05
# scores_deque_mean[-1]: 30.05

# %% [markdown]
# ### 05.b: BATCH_SIZE = 128
#
# This is the same as the 04. case above, since BATCH_SIZE = 128 is the default.

# %% [markdown]
# ### 05.c: BATCH_SIZE = 256

# %%
agent = Agent(state_size=state_size, action_size=action_size, 
              actor_fc1_units = 128, actor_fc2_units = 128, 
              critic_fc1_units = 128, critic_fc2_units = 128, 
              sigma = 0.05, 
              LR_ACTOR = 5e-4, LR_CRITIC = 5e-4,
              use_BatchNorm=True,
              use_clipping=False,
              BATCH_SIZE = 256)

with active_session():
    scores, scores_deque_mean, num_episodes_solved, solved = train(n_episodes=500, path_name='checkpoint_05c')
    
print('\rscores_deque_mean[-1]: {:.2f}'.format(scores_deque_mean[-1]))
plot_scores(scores, scores_deque_mean, 'DDPG - BATCH_SIZE = 256', num_episodes_solved, solved, full_run=True)
# Out:
# Episode 25	Average Score: 1.14	Score: 1.47
# Episode 50	Average Score: 2.76	Score: 7.363
# Episode 75	Average Score: 4.39	Score: 10.01
# Episode 100	Average Score: 6.60	Score: 17.60
# Episode 125	Average Score: 11.21	Score: 32.49
# Episode 150	Average Score: 17.92	Score: 21.03
# Episode 175	Average Score: 24.35	Score: 39.15
# Episode 200	Average Score: 28.98	Score: 25.74
# Episode 206	Average Score: 30.16	Score: 33.68
# Environment solved in 106 episodes!	Average Score: 30.16
# scores_deque_mean[-1]: 30.16

# %% [markdown]
# ### Observations:
#
# => In comparison with BATCH_SIZE = 128, a BATCH_SIZE = 64 slows down the learning, and the learning curve of the individual scores exhibits many wild swings.
#
# => BATCH_SIZE = 256 makes the learning a bit faster in comparison to the 128 case.
#
# => Use BATCH_SIZE = 256 going forward

# %% [markdown]
# ### 06. Number of units in the hidden layers of the neural networks
#
# 06.a: fc_units = 128
#
# 06.b: fc_units = 256

# %% [markdown]
# ### 06.a fc_units = 128
#
# This is the same as case 05.c above, since fc_units = 128 is the default.

# %% [markdown]
# ### 06.b: fc_units = 256

# %%
agent = Agent(state_size=state_size, action_size=action_size, 
              actor_fc1_units = 256, actor_fc2_units = 256, 
              critic_fc1_units = 256, critic_fc2_units = 256, 
              sigma = 0.05, 
              LR_ACTOR = 5e-4, LR_CRITIC = 5e-4,
              use_BatchNorm=True,
              use_clipping=False,
              BATCH_SIZE = 256)

with active_session():
    scores, scores_deque_mean, num_episodes_solved, solved = train(n_episodes=500, path_name='checkpoint_05c')
    
print('\rscores_deque_mean[-1]: {:.2f}'.format(scores_deque_mean[-1]))
plot_scores(scores, scores_deque_mean, 'DDPG - BATCH_SIZE = 256', num_episodes_solved, solved, full_run=True)
# Out:
# Episode 25	Average Score: 2.09	Score: 2.13
# Episode 50	Average Score: 4.33	Score: 11.07
# Episode 75	Average Score: 7.54	Score: 5.020
# Episode 100	Average Score: 10.69	Score: 30.66
# Episode 125	Average Score: 17.50	Score: 33.70
# Episode 150	Average Score: 24.41	Score: 34.42
# Episode 175	Average Score: 29.37	Score: 38.28
# Episode 180	Average Score: 30.01	Score: 36.72
# Environment solved in 80 episodes!	Average Score: 30.01
# scores_deque_mean[-1]: 30.01

# %% [markdown]
# ### Observations:
#
# => Case 06.b has been the fastest learner to achieve an average score of +30. Putting this agent along with the chosen set of hyperparameters forward.

# %%
  #  env.close()
